# %%
import matplotlib.pyplot as plt

# Example data
unordered_start_times = [ride["start"] for ride in rides]
optimized_start_times = [ride["start"] for ride in optimized_rides]
optimized_assets = [ride["asset"] for ride in optimized_rides]

def plot_start_times(times, assets=None, title=''):
    plt.figure(figsize=(10, 6))
    if assets:
        unique_assets = list(set(assets))
        colors = plt.cm.get_cmap('tab10', len(unique_assets))
        for i, asset in enumerate(unique_assets):
            asset_times = [times[j] for j in range(len(times)) if assets[j] == asset]
            plt.scatter(asset_times, [i] * len(asset_times), label=asset, color=colors(i))
        plt.yticks(range(len(unique_assets)), unique_assets)
        plt.legend()
    else:
        plt.scatter(times, [1] * len(times), color='blue', alpha=0.6)
        plt.yticks([1], ['Rides'])
    plt.xlabel('Start Time')
    plt.title(title)
    plt.show()

# Plot unordered ride start times
plot_start_times(unordered_start_times, title='Unordered Ride Start Times')

# Plot optimized ride start times
plot_start_times(optimized_start_times, optimized_assets, title='Optimized Ride Start Times')
# Out:
# C:\Users\cyberwitch\AppData\Local\Temp\ipykernel_26616\1802943124.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap('tab10', len(unique_assets))
